# %% [markdown]
# <a href="https://colab.research.google.com/github/rajanpandi/car_sales_data/blob/main/car_algoritham_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/all_state_after_cleaning_droped_columns (1).csv")

# %%
df["Max Power"].value_counts()
# Out:
# Max Power
# 81.80bhp@6000rpm     305
# 81.86bhp@6000rpm     276
# 88.50bhp@6000rpm     265
# 83.1bhp@6000rpm      194
# 74bhp@4000rpm        171
#                     ...
# 65.39bhp@6000rpm       1
# 182.46bhp@4000rpm      1
# 69bhp@4500rpm          1
# 321bhp@5800rpm         1
# 88.5bhp@4200rpm        1
# Name: count, Length: 739, dtype: int64

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    Unnamed: 0  it      ft         bt        km transmission  ownerNo      oem  \
# 0           0   0  Petrol  Hatchback  1,20,000       Manual        3   Maruti
# 1           1   0  Petrol        SUV    32,706       Manual        2     Ford
# 2           2   0  Petrol  Hatchback    11,949       Manual        1     Tata
# 3           3   0  Petrol      Sedan    17,794       Manual        1  Hyundai
# 4           4   0  Diesel        SUV    60,000       Manual        1   Maruti
#
#                 model  modelYear  centralVariantId               variantName  \
# 0      Maruti Celerio       2015              3979                       VXI
# 1       Ford Ecosport       2018              6087  1.5 Petrol Titanium BSIV
# 2          Tata Tiago       2018              2983           1.2 Revotron XZ
# 3       Hyundai Xcent       2014              1867        1.2 Kappa S Option
# 4  Maruti SX4 S Cross       2015              4277             DDiS 200 Zeta
#
# ...

# %%
df["km"]=df["km"].apply(lambda x:x.replace(",","")).astype(int)

# %%
df["Insurance Validity"].value_counts()
# Out:
# Insurance Validity
# Third Party insurance    3948
# Comprehensive            3096
# Third Party               608
# Zero Dep                  296
# Not Available             215
# 1                           4
# 2                           1
# Name: count, dtype: int64

# %%
df["Insurance Validity"]=df["Insurance Validity"].apply(lambda x:x.replace("1","First party")).apply(lambda x:x.replace("2","second party"))

# %%
df["Insurance Validity"].value_counts()
# Out:
# Insurance Validity
# Third Party insurance    3948
# Comprehensive            3096
# Third Party               608
# Zero Dep                  296
# Not Available             215
# First party                 4
# second party                1
# Name: count, dtype: int64

# %%
#ownership & ownerno, both same value so we reamoved any one column

# %%
df.drop(["Ownership"],axis=1,inplace=True)

# %%
df["Engine"].value_counts()
# Out:
# Engine
# 1197 CC    1608
# 998 CC      639
# 1199 CC     487
# 1497 CC     450
# 1248 CC     419
#            ...
# 4134 CC       1
# 1468 CC       1
# 2997 CC       1
# 2894 CC       1
# 2489 CC       1
# Name: count, Length: 145, dtype: int64

# %%
df["Engine"]=df["Engine"].apply(lambda x:x.replace("CC",""))

# %%
df["Engine"].value_counts().head(5)
# Out:
# Engine
# 1197     1608
# 998       639
# 1199      487
# 1497      450
# 1248      419
# Name: count, dtype: int64

# %%
df["Torque"]=df["Torque"].apply(lambda x:x.replace("Nm",""))

# %%
#Torque & Max Torque both column same value so we removed any one column

# %%
df.drop(["Max Torque"],axis=1,inplace=True)

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    it      ft         bt      km transmission  ownerNo     oem  \
# 0   0  Petrol  Hatchback  120000       Manual        3  Maruti
# 1   0  Petrol        SUV   32706       Manual        2    Ford
# 2   0  Petrol  Hatchback   11949       Manual        1    Tata
#
#             model  modelYear  centralVariantId               variantName  \
# 0  Maruti Celerio       2015              3979                       VXI
# 1   Ford Ecosport       2018              6087  1.5 Petrol Titanium BSIV
# 2      Tata Tiago       2018              2983           1.2 Revotron XZ
#
#     price  priceActual     Insurance Validity Fuel Type   RTO  Features  \
# 0  400000      40000.0  Third Party insurance    Petrol  KA51         8
# 1  811000      81100.0          Comprehensive    Petrol  KA05         8
# 2  585000      58500.0          Comprehensive    Petrol  KA03         8
#
#    Comfort & Convenience  Interior  Exterior  Safety  Mileage Engine  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8168 entries, 0 to 8167
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   it                     8168 non-null   int64
#  1   ft                     8168 non-null   object
#  2   bt                     8168 non-null   object
#  3   km                     8168 non-null   int64
#  4   transmission           8168 non-null   object
#  5   ownerNo                8168 non-null   int64
#  6   oem                    8168 non-null   object
#  7   model                  8168 non-null   object
#  8   modelYear              8168 non-null   int64
#  9   centralVariantId       8168 non-null   int64
#  10  variantName            8168 non-null   object
#  11  price                  8168 non-null   int64
#  12  priceActual            8168 non-null   float64
#  13  Insurance Validity     8168 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in df.columns:
  if df[i].dtype=="object":
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8168 entries, 0 to 8167
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   it                     8168 non-null   int64
#  1   ft                     8168 non-null   int64
#  2   bt                     8168 non-null   int64
#  3   km                     8168 non-null   int64
#  4   transmission           8168 non-null   int64
#  5   ownerNo                8168 non-null   int64
#  6   oem                    8168 non-null   int64
#  7   model                  8168 non-null   int64
#  8   modelYear              8168 non-null   int64
#  9   centralVariantId       8168 non-null   int64
#  10  variantName            8168 non-null   int64
#  11  price                  8168 non-null   int64
#  12  priceActual            8168 non-null   float64
#  13  Insurance Validity     8168 non-null   int64
#  14  Fuel Type              8168 non-null   int64
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
for i in df.columns:
  print(i,df[i].skew())
# Out:
# it 0.0
# ft -0.7210608923143776
# bt -0.109372826134991
# km 50.20061471826777
# transmission -0.9998959892913404
# ownerNo 1.88745463398032
# oem 0.1158178448955773
# model 0.37659832730822485
# modelYear -0.8937221224107548
# centralVariantId 0.009888771522443482
# variantName -0.24338143625880604
# price 10.178867149608976
# priceActual 2.88428200871167
# Insurance Validity -0.3532933048542573
# Fuel Type -0.7210608923143776
# RTO -0.15174351233065494
# Features -7.779758599687562
# Comfort & Convenience -0.30508405683024864
# Interior -0.7186445991621028
# Exterior -0.3143741064079378
# Safety -0.9581377224132834
# Mileage 5.046350623910712
# Engine 0.8618088881859403
# Max Power -0.4588072816405932
# Torque 0.266923801168183
# Color -0.7092805252180667
# Engine Type -0.5297470154656888
# No of Cylinder 5.044081893199738
# Values per Cylinder 53.97420970657477
# Value Configuration 1.4535252303308648
# Fuel Suppy System -0.2477769217482549

# %%
for i in df.columns:
  print(i,":",df[i].nunique())
# Out:
# it : 1
# ft : 5
# bt : 10
# km : 4004
# transmission : 2
# ownerNo : 6
# oem : 33
# model : 307
# modelYear : 28
# centralVariantId : 2667
# variantName : 2117
# price : 1380
# priceActual : 1784
# Insurance Validity : 7
# Fuel Type : 5
# RTO : 462
# Features : 9
# Comfort & Convenience : 6
# Interior : 5
# Exterior : 6
# Safety : 5
# Mileage : 31
# Engine : 145
# Max Power : 739
# Torque : 355
# Color : 149
# Engine Type : 509
# No of Cylinder : 8
# Values per Cylinder : 5
# Value Configuration : 13
# Fuel Suppy System : 81

# %%
cat=[]
coun=[]
for i in df.columns:
  if df[i].nunique()<=33:
    cat.append(i)
  else:
    coun.append(i)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import norm

# %%
for i in coun:
  print(i)
  sns.boxplot(df[i])
  plt.show()
# Out:
# km
# model
# centralVariantId
# variantName
# price
# priceActual
# RTO
# Engine
# Max Power
# Torque
# Color
# Engine Type
# Fuel Suppy System

# %%
q1=df["km"].quantile(.25)
q3=df["km"].quantile(.75)
iqr=q3-q1

# %%
upper_limit=q3+(1.5*iqr)
lower_limt=q1-(1.5*iqr)
lower_limt,upper_limit
# Out:
# (-44448.125, 154668.875)

# %%
df1=df.copy()

# %%
df.shape
# Out:
# (8168, 31)

# %%
df.loc[(df["km"]> upper_limit) | (df["km"]< lower_limt)]
# Out:
#       it  ft  bt       km  transmission  ownerNo  oem  model  modelYear  \
# 296    0   1   7   164000             1        2   17    143       2014
# 325    0   1   7   174000             0        3   30    277       2014
# 328    0   1   4   199000             1        2   30    281       2011
# 1194   0   1   4   162000             1        1   30    281       2008
# 1198   0   1   7   180000             1        2   30    277       2011
# 1245   0   1   7   174000             1        1   30    277       2018
# 1248   0   1   7   170402             0        2   32    304       2010
# 1264   0   1   4   157000             1        2   30    282       2016
# 1364   0   1   4   169219             1        2   30    281       2014
# 1435   0   1   7   156039             1        2   30    277       2012
# 1495   0   1   4   800000             1        1   30    282       2018
# 1496   0   1   8  5500000             0        1   21    190       2018
# ...

# %%
# Assuming you have already defined upper_limit and lower_limit
df = df.loc[(df["km"] <= upper_limit) & (df["km"] >= lower_limt)]

# %%
sns.boxplot(df["km"])
plt.show()

# %%
df.shape
# Out:
# (8120, 31)

# %%
#price

q1=df["price"].quantile(.25)
q3=df["price"].quantile(.75)
iqr=q3-q1

# %%
upper_limit=q3+(1.5*iqr)
lower_limt=q1-(1.5*iqr)
lower_limt,upper_limit
# Out:
# (-425000.0, 1775000.0)

# %%
df.loc[(df["price"]> upper_limit) | (df["price"]< lower_limt)]
# Out:
#       it  ft  bt      km  transmission  ownerNo  oem  model  modelYear  \
# 5      0   1   7   20000             1        1   12     98       2020
# 19     0   1   8  100000             0        3    1     15       2011
# 23     0   4   8   50000             0        2   21    204       2016
# 27     0   4   8   33000             0        1   21    193       2017
# 29     0   1   8   40000             0        2    0      3       2016
# ...   ..  ..  ..     ...           ...      ...  ...    ...        ...
# 8079   0   1   7   29000             0        1   12     98       2021
# 8080   0   1   8   23000             0        1    1     12       2018
# 8089   0   1   7    2000             0        1   17    136       2023
# 8094   0   4   7   32000             0        1    0      7       2018
# 8142   0   4   7   10000             0        1   13    104       2022
#
#       centralVariantId  variantName    price  priceActual  Insurance Validity  \
# ...

# %%
# Assuming you have already defined upper_limit and lower_limit
df = df.loc[(df["price"] <= upper_limit) & (df["price"] >= lower_limt)]

# %%
sns.boxplot(df["price"])
plt.show()

# %%
df.shape
# Out:
# (7267, 31)

# %%
#price & actual price both same value:
df.drop(["priceActual"],axis=1,inplace=True)

# %%
import plotly.express as px
px.box(df,y="km",points="all")#,color="model"
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head(3)
# Out:
#    it  ft  bt      km  transmission  ownerNo  oem  model  modelYear  \
# 0   0   4   2  120000             1        3   20    155       2015
# 1   0   4   7   32706             1        2    6     48       2018
# 2   0   4   2   11949             1        1   29    265       2018
#
#    centralVariantId  variantName   price  Insurance Validity  Fuel Type  RTO  \
# 0              3979         1771  400000                   4          4  164
# 1              6087          285  811000                   0          4  135
# 2              2983          128  585000                   0          4  133
#
#    Features  Comfort & Convenience  Interior  Exterior  Safety  Mileage  \
# 0         8                     10         7         5      13     23.0
# 1         8                     10         7         5      13     17.0
# 2         8                     10         7         5      13     23.0
#
#    Engine  Max Power  Torque  Color  Engine Type  No of Cylinder  \
# ...

# %%
x=df.drop(["price"],axis=1)
y=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x)
x_scaler = scaler.transform(x)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression().fit(x_train,y_train)
y_pred=model1.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 49669343725.92348
# 165137.472627267
# 0.5926622803613825

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 17465297936.97643
# 87245.67068244358
# 0.8567672914360667

# %%
from sklearn.svm import SVR
model3 = SVR().fit(x_train,y_train)
y_pred=model3.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 126435222018.93156
# 263453.1848085135
# -0.036893809255507115

# %%
from sklearn.neighbors import KNeighborsRegressor
model4 = KNeighborsRegressor().fit(x_train,y_train)
y_pred=model4.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))#priority 2
print(r2_score(y_test,y_pred)) #priority 1
# Out:
# 50617523376.33603
# 159874.31128233354
# 0.5848862698962953

# %%
from xgboost import XGBRegressor
model5 = XGBRegressor().fit(x_train,y_train)
y_pred=model5.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))#priority 2
print(r2_score(y_test,y_pred)) #priority 1
# Out:
# 14182641116.53734
# 78660.96962330324
# 0.8836883224642242

# %%
from sklearn.tree import DecisionTreeRegressor
# Initialize the regressor
regressor = DecisionTreeRegressor()

# Fit the model on your training data
regressor.fit(x_train, y_train)

# Make predictions on the test data
y_pred = regressor.predict(x_test)

print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))#priority 2
print(r2_score(y_test,y_pred)) #priority 1
# Out:
# 37378916986.8437
# 120445.16951018161
# 0.6934559294360998

# %% [markdown]
# #droped column

# %%
df["Color"].value_counts()
# Out:
# Color
# 85     1967
# 136    1356
# 114    1133
# 108     734
# 9       504
#        ...
# 139       1
# 109       1
# 140       1
# 144       1
# 86        1
# Name: count, Length: 141, dtype: int64

# %%
df.head(1)
# Out:
#    it  ft  bt      km  transmission  ownerNo  oem  model  modelYear  \
# 0   0   4   2  120000             1        3   20    155       2015
#
#    centralVariantId  variantName   price  Insurance Validity  Fuel Type  RTO  \
# 0              3979         1771  400000                   4          4  164
#
#    Features  Comfort & Convenience  Interior  Exterior  Safety  Mileage  \
# 0         8                     10         7         5      13     23.0
#
#    Engine  Max Power  Torque  Color  Engine Type  No of Cylinder  \
# 0     143        523     336    136          293             3.0
#
#    Values per Cylinder  Value Configuration  Fuel Suppy System
# 0                  4.0                    3                 53

# %%
x1=df.drop(["price","it","centralVariantId","variantName","Engine"],axis=1)
y1=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x1)
x_scaler = scaler.transform(x1)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y1,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 23216528710.457916
# 101811.01866839637
# 0.8163226248133207

# %%
x2=df.drop(["price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color"],axis=1)
y2=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x2)
x_scaler = scaler.transform(x2)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y2,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 20215420307.578968
# 95794.54700937355
# 0.8347437875689825

# %%
x3=df.drop(["price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color","model"],axis=1)
y2=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x3)
x_scaler = scaler.transform(x3)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y2,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 24564470259.061066
# 107534.27289157515
# 0.8006385312716208

# %%
df.head(1)
# Out:
#    it  ft  bt      km  transmission  ownerNo  oem  model  modelYear  \
# 0   0   4   2  120000             1        3   20    155       2015
#
#    centralVariantId  variantName   price  Insurance Validity  Fuel Type  RTO  \
# 0              3979         1771  400000                   4          4  164
#
#    Features  Comfort & Convenience  Interior  Exterior  Safety  Mileage  \
# 0         8                     10         7         5      13     23.0
#
#    Engine  Max Power  Torque  Color  Engine Type  No of Cylinder  \
# 0     143        523     336    136          293             3.0
#
#    Values per Cylinder  Value Configuration  Fuel Suppy System
# 0                  4.0                    3                 53

# %%
x3.head(1)
# Out:
#    ft  bt      km  transmission  ownerNo  oem  modelYear  Insurance Validity  \
# 0   4   2  120000             1        3   20       2015                   4
#
#    Fuel Type  Features  Comfort & Convenience  Interior  Exterior  Safety  \
# 0          4         8                     10         7         5      13
#
#    Mileage  Torque  Engine Type  No of Cylinder  Values per Cylinder  \
# 0     23.0     336          293             3.0                  4.0
#
#    Value Configuration  Fuel Suppy System
# 0                    3                 53

# %%
x4=df.drop(["price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color","model","Torque","Engine Type","No of Cylinder"],axis=1)
y2=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x4)
x_scaler = scaler.transform(x4)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y2,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 21378891897.068077
# 104905.63064886958
# 0.8321158461986938

# %%
x5=df.drop(["price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color","model","Torque","Engine Type","No of Cylinder","Values per Cylinder","Value Configuration","Fuel Suppy System"],axis=1)
y2=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x5)
x_scaler = scaler.transform(x5)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y2,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 23829285096.476658
# 107642.76778939643
# 0.8117179698004714

# %%
x6=df.drop(["price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color","model","Torque","Engine Type","No of Cylinder","Values per Cylinder","Value Configuration","Fuel Suppy System","Features","Comfort & Convenience","Interior","Exterior","Safety"],axis=1)
y2=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x6)
x_scaler = scaler.transform(x6)

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y2,test_size=0.25)

from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 26749057845.601627
# 115721.56518773096
# 0.7940904552649665

# %%
from sklearn.ensemble import RandomForestRegressor
model2_1 = RandomForestRegressor(n_estimators=500,min_samples_split=5).fit(x_train,y_train)
y_pred=model2_1.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 26433113986.658104
# 115366.85497481392
# 0.7965225355472851

# %%
from xgboost import XGBRegressor
model5 = XGBRegressor().fit(x_train,y_train)
y_pred=model5.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))#priority 2
print(r2_score(y_test,y_pred)) #priority 1
# Out:
# 26690591334.381474
# 116208.37811672314
# 0.7945405201897603

# %%
x6.head(1)
# Out:
#    ft  bt      km  transmission  ownerNo  oem  modelYear  Insurance Validity  \
# 0   4   2  120000             1        3   20       2015                   4
#
#    Fuel Type  Mileage
# 0          4     23.0

# %%
x7=df.drop(["ft","price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color","model","Torque","Engine Type","No of Cylinder","Values per Cylinder","Value Configuration","Fuel Suppy System","Features","Comfort & Convenience","Interior","Exterior","Safety"],axis=1)
y2=df["price"]

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #(data - mean(data))/ Sd(data)
scaler.fit(x7)
x_scaler = scaler.transform(x7)

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaler,y2,test_size=0.25)

from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 26073344049.01366
# 117903.40177885666
# 0.8030094458309365

# %% [markdown]
# # **#without scalling**

# %%
x8=df.drop(["ft","price","it","centralVariantId","variantName","Engine","RTO","Max Power","Color","model","Torque","Engine Type","No of Cylinder","Values per Cylinder","Value Configuration","Fuel Suppy System","Features","Comfort & Convenience","Interior","Exterior","Safety"],axis=1)
y2=df["price"]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x8,y2,test_size=0.25)

from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 26960634700.3265
# 117301.982038311
# 0.7995516728130557

# %%
pickle.dump(model2,open('model1.pkl','wb'))

# %%
train_model = pickle.load(open('model1.pkl', 'rb'))

# %%
import numpy as np
import pickle

# %% [markdown]
# # **#with scalling train model**

# %%
pickle.dump(model2,open('model.pkl','wb'))

# %%
train_model = pickle.load(open('model.pkl', 'rb'))

# %%
x7.head(1)
# Out:
#    bt      km  transmission  ownerNo  oem  modelYear  Insurance Validity  \
# 0   2  120000             1        3   20       2015                   4
#
#    Fuel Type  Mileage
# 0          4     23.0

# %%
import numpy as np

# Prepare input data
input_data = (2,1000,1, 20, 3,4,3,23,2023)  # Example values
arrange_array = np.asarray(input_data).reshape(1, -1)

# Assuming scaler is already loaded and fitted
std_data = scaler.transform(arrange_array)  # Use transform() if scaler is already fitted

# Predict with the loaded model
prediction = train_model.predict(std_data)

print("Predicted value:", prediction)
# Out:
# Predicted value: [99870.05]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names

# %%
df2=pd.read_csv("/content/all_state_after_cleaning_droped_columns (1).csv")

# %%
pip install streamlit

# %%
import pickle
import streamlit as st

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.168.198.30

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.168.198.30:8501
#
# your url is: https://wise-zebras-hide.loca.lt
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#   Stopping...
# ^C

# %%
y2=df["price"]
y2
# Out:
# 0       400000
# 1       811000
# 2       585000
# 3       462000
# 4       790000
#          ...
# 8163    509999
# 8164    180000
# 8165    550000
# 8166    140000
# 8167    500000
# Name: price, Length: 7267, dtype: int64
